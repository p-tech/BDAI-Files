# %% [markdown]
# <a href="https://colab.research.google.com/github/p-tech/BDAI-Files/blob/main/Google_Capture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import csv
from bs4 import BeautifulSoup
import time
import random

def getCountry(countries):
    # Placeholder for your actual getCountry function
    return "gl=uk&hl=en&cr=countryGB"

    #GB, US, AU

# Define the number of results and headers (placeholders)
number_results = 5
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
countries = "gb"

# Open a CSV file to write data (using newline='' to avoid blank lines)
with open('output_file_new.csv', 'w', newline='') as csvfile:

    writer = csv.writer(csvfile)

    dataArray = []

    with open('keywords_file.csv', 'r') as file:

        lineNumber = 0

        for line in file:
            # Indented the code block within the for loop
            lineClean = line.strip().replace('\n', '').replace('\r', '')
            line = line.strip().replace(" ", "+").replace('\n', '').replace('\r', '')
            countryInfo = getCountry(countries)
            query = f"https://www.google.co.uk/search?q={line}&num={number_results}&lr=lang_en&{countryInfo}"

            print(lineClean)
            #print(query)

            page = requests.get(query, headers = headers)

            print (page.status_code, page.reason, page.headers)

            soup = BeautifulSoup(page.content, 'html.parser')

            row_data = [lineClean]

            mydiv = soup.findAll('div', {"class": "g"})

            for div in mydiv:
                site = div.find('cite', {'class': 'qLRx3b', 'role': 'text'})
                linkURL = div.find('a', attrs={'jsname': 'UWckNb'})
                if site:
                    url_text = site.contents[0].strip()
                    print(url_text)
                    row_data.extend([url_text])
                if linkURL:
                    url = linkURL.get('href')
                    print(url)
                    row_data.extend([url])

            numberRND = random.randint(5, 8)
            print (numberRND)
            time.sleep(3)
            lineNumber += 1

            writer.writerow(row_data)


print("CSV file writing complete.")
# Out:
# ﻿Nike men's running t-shirt
# 429 Too Many Requests {'Date': 'Sun, 26 Jan 2025 22:08:10 GMT', 'Pragma': 'no-cache', 'Expires': 'Fri, 01 Jan 1990 00:00:00 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate', 'Content-Type': 'text/html', 'Server': 'HTTP server (unknown)', 'Content-Length': '3460', 'X-XSS-Protection': '0'}
# 6
# Adidas black gym bag
# 429 Too Many Requests {'Date': 'Sun, 26 Jan 2025 22:08:14 GMT', 'Pragma': 'no-cache', 'Expires': 'Fri, 01 Jan 1990 00:00:00 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate', 'Content-Type': 'text/html', 'Server': 'HTTP server (unknown)', 'Content-Length': '3403', 'X-XSS-Protection': '0'}
# 8
# Black Nike air jordans
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-98215c22d180> in <cell line: 0>()
#      37             #print(query)
#      38
# ...

# %%
df.head()
# Out:
#                           Data
# 0  ﻿Nike+men's+running+t-shirt
# 1         Adidas+black+gym+bag
# 2       Black+Nike+air+jordans
# 3   adidas+black+mens+trainers
# 4      cloudform+blue+trainers
