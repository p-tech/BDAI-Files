# %%
import advertools as adv
import pandas as pd
from ua_parser import user_agent_parser

# %%
# !head -n 4 access_log
# Out:
# www.slottrackscenics.co.uk 91.108.178.78 - - [28/Apr/2024:04:08:18 +0100] "GET /home-track-pit-lane-2/pit-lane-version-2b-copy/ HTTP/1.1" 301 - "https://www.slottrackscenics.co.uk/" "Mozilla/5.0 (Linux x86_64; rv:114.0) Gecko/20100101 Firefox/114.0"
# www.slottrackscenics.co.uk 91.108.178.78 - - [28/Apr/2024:04:08:21 +0100] "GET /wp-content/uploads/2015/11/Pit-Lane-version-2B-Copy.jpg HTTP/1.1" 200 263877 "https://www.slottrackscenics.co.uk/home-track-pit-lane-2/pit-lane-version-2b-copy/" "Mozilla/5.0 (Linux x86_64; rv:114.0) Gecko/20100101 Firefox/114.0"
# www.slottrackscenics.co.uk 124.243.132.146 - - [28/Apr/2024:04:08:27 +0100] "GET /shop/adverts/advert-boards-3-a/?add_to_wishlist=530&_wpnonce=897beb0140 HTTP/1.1" 200 174662 "-" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
# www.slottrackscenics.co.uk 190.92.209.184 - - [28/Apr/2024:04:09:36 +0100] "GET /shop/trackside-extras/bv-burger-van/?add_to_wishlist=1096&_wpnonce=cada0a62b4 HTTP/1.1" 200 175504 "-" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"

# %%
# parse the log file and save as .parquet format
adv.logs_to_df(log_file='access_log',
               output_file='access_log.parquet',
               errors_file='access.txt',
               log_format='([^-]*) ([^-]*) ([^ ]*) ([^ ]*) \[([^]]*)\] "([^"]*)" ([^ ]*) ([^ ]*) "([^"]*)" "([^"]*)"',
               fields=['host','client','userid','','datetime', 'request', 'size','status','referer','user_agent']
               )
# Out:
# Parsed          10,857 lines.

# %%
logs_df = pd.read_parquet('access_log.parquet')

logs_df['datetime'] = pd.to_datetime(logs_df['datetime'], format='%d/%b/%Y:%H:%M:%S %z')

logs_df
# Out:
#                              host           client userid     \
# 0      www.slottrackscenics.co.uk    91.108.178.78      -  -
# 1      www.slottrackscenics.co.uk    91.108.178.78      -  -
# 2      www.slottrackscenics.co.uk  124.243.132.146      -  -
# 3      www.slottrackscenics.co.uk   190.92.209.184      -  -
# 4      www.slottrackscenics.co.uk   110.238.108.75      -  -
# ...                           ...              ...    ... ..
# 10853  www.slottrackscenics.co.uk  124.243.133.152      -  -
# 10854  www.slottrackscenics.co.uk     49.0.203.181      -  -
# 10855  www.slottrackscenics.co.uk  103.136.221.239      -  -
# 10856  www.slottrackscenics.co.uk   101.44.163.232      -  -
# 10857  www.slottrackscenics.co.uk   190.92.213.155      -  -
#
#                        datetime  \
# 0     2024-04-28 04:08:18+01:00
# 1     2024-04-28 04:08:21+01:00
# 2     2024-04-28 04:08:27+01:00
# 3     2024-04-28 04:09:36+01:00
# 4     2024-04-28 04:09:41+01:00
# ...                         ...
# 10853 2024-04-29 09:02:25+01:00
# 10854 2024-04-29 09:03:02+01:00
# 10855 2024-04-29 09:03:32+01:00
# 10856 2024-04-29 09:03:28+01:00
# 10857 2024-04-29 09:05:02+01:00
#
#                                                  request size  status  \
# 0      GET /home-track-pit-lane-2/pit-lane-version-2b...  301       -
# 1      GET /wp-content/uploads/2015/11/Pit-Lane-versi...  200  263877
# 2      GET /shop/adverts/advert-boards-3-a/?add_to_wi...  200  174662
# 3      GET /shop/trackside-extras/bv-burger-van/?add_...  200  175504
# 4      GET /shop/figures/sra-figures/sra-06-pit-crew-...  200  187871
# ...                                                  ...  ...     ...
# 10853  GET /shop/pit-lane-series/pltr-3-three-tyre-ra...  200  166329
# 10854  GET /shop/decals/gen-dec/dec-3-champagne-bottl...  200  154466
# 10855  GET /wp-content/uploads/2017/09/1.5-Straight-F...  200   61741
# 10856  GET /shop/adverts/advert-boards-1/?add_to_wish...  200  170296
# 10857  GET /shop/mtps/mtp-1b-arc-pro-powerbase-piece/...  200  182843
#
#                                                  referer  \
# 0                    https://www.slottrackscenics.co.uk/
# 1      https://www.slottrackscenics.co.uk/home-track-...
# 2                                                      -
# 3                                                      -
# 4                                                      -
# ...                                                  ...
# 10853                                                  -
# 10854                                                  -
# 10855                                                  -
# 10856                                                  -
# 10857                                                  -
#
#                                               user_agent
# 0      Mozilla/5.0 (Linux x86_64; rv:114.0) Gecko/201...
# 1      Mozilla/5.0 (Linux x86_64; rv:114.0) Gecko/201...
# 2      Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3      Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 4      Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# ...                                                  ...
# 10853  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 10854  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 10855  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 10856  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 10857  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
# [10858 rows x 10 columns]

# %%
# %%time
host_df = adv.reverse_dns_lookup(logs_df['client'])
print(f'Rows, columns: {host_df.shape}')
host_df.head(15)
# Rows, columns: (1210, 9)
# CPU times: user 745 ms, sys: 729 ms, total: 1.47 s
# Wall time: 21.1 s
# Out:
# 2024-05-16 19:36:42,924 | INFO | utils.py:157 | _init_num_threads | NumExpr defaulting to 8 threads.
# Rows, columns: (1177, 9)
# CPU times: user 861 ms, sys: 646 ms, total: 1.51 s
# Wall time: 26.7 s
#                                  ip_address  count  cum_count      perc  \
# 0                                 127.0.0.1   4048       4048  0.372813
# 1   2a00:23c6:371e:a701:64aa:346d:e627:7db8    333       4381  0.030669
# 2   2a01:4b00:833c:8a00:c0f6:c85e:9f13:c435    239       4620  0.022011
# 3   2001:8004:27e0:803b:35ea:d550:c0c3:93cf    222       4842  0.020446
# 4    2001:8004:cc1:4d12:369b:fa60:33c7:1e2a    166       5008  0.015288
# 5   2a01:cb06:9061:45ac:fae4:eec3:6797:93e6    123       5131  0.011328
# 6                              75.168.135.5    113       5244  0.010407
# 7                               82.4.138.38    110       5354  0.010131
# 8                              89.22.225.45    109       5463  0.010039
# 9                             66.249.64.129    100       5563  0.009210
# 10                           175.35.117.232     73       5636  0.006723
# 11                            194.31.79.227     71       5707  0.006539
# 12  2a00:23c6:760c:3101:a4a0:8795:aaa2:112f     70       5777  0.006447
# 13                2a09:bac2:3132:191::28:9a     69       5846  0.006355
# 14    2806:267:3423:2b4:dd45:f7af:654a:1f8c     64       5910  0.005894
#
#     cum_perc                                           hostname  \
# 0   0.372813                                          localhost
# 1   0.403481                                               None
# 2   0.425493                                               None
# 3   0.445938                                               None
# 4   0.461227                                               None
# 5   0.472555  2a01cb06906145acfae4eec3679793e6.ipv6.abo.wana...
# 6   0.482962                        75-168-135-5.mpls.qwest.net
# 7   0.493093  shep-15-b2-v4wan-167885-cust37.vm44.cable.virg...
# 8   0.503131              host-89-22-225-45.hosted-by-vdsina.ru
# 9   0.512341                  crawl-66-249-64-129.googlebot.com
# 10  0.519064            n175-35-117-232.adl2.sa.optusnet.com.au
# 11  0.525603                                          sunucu.al
# 12  0.532050                                               None
# 13  0.538405                                               None
# 14  0.544299                                               None
#
#                                             aliaslist  \
# 0                              1.0.0.127.in-addr.arpa
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   6.e.3.9.7.9.7.6.3.c.e.e.4.e.a.f.c.a.5.4.1.6.0....
# 6                           5.135.168.75.in-addr.arpa
# 7                            38.138.4.82.in-addr.arpa
# 8                           45.225.22.89.in-addr.arpa
# 9                          129.64.249.66.in-addr.arpa
# 10                        232.117.35.175.in-addr.arpa
# 11                         227.79.31.194.in-addr.arpa
# 12                                               None
# 13                                               None
# 14                                               None
#
#                                  ipaddrlist                  errors
# 0                                 127.0.0.1                    None
# 1                                      None  [Errno 1] Unknown host
# 2                                      None  [Errno 1] Unknown host
# 3                                      None  [Errno 1] Unknown host
# 4                                      None  [Errno 1] Unknown host
# 5   2a01:cb06:9061:45ac:fae4:eec3:6797:93e6                    None
# 6                              75.168.135.5                    None
# 7                               82.4.138.38                    None
# 8                              89.22.225.45                    None
# 9                             66.249.64.129                    None
# 10                           175.35.117.232                    None
# 11                            194.31.79.227                    None
# 12                                     None  [Errno 1] Unknown host
# 13                                     None  [Errno 1] Unknown host
# 14                                     None  [Errno 1] Unknown host

# %%
ip_host_dict = dict(zip(host_df['ip_address'], host_df['hostname']))
logs_df['hostname'] = [ip_host_dict[ip] for ip in logs_df['client']]

# %%
request_url_df = adv.url_to_df(logs_df['request'])
request_url_df = request_url_df.add_prefix('request_')
request_url_df.head(10)
# Out:
#                                          request_url  request_scheme  \
# 0  GET /home-track-pit-lane-2/pit-lane-version-2b...             NaN
# 1  GET /wp-content/uploads/2015/11/Pit-Lane-versi...             NaN
# 2  GET /shop/adverts/advert-boards-3-a/?add_to_wi...             NaN
# 3  GET /shop/trackside-extras/bv-burger-van/?add_...             NaN
# 4  GET /shop/figures/sra-figures/sra-06-pit-crew-...             NaN
# 5  GET /wp-content/uploads/2019/05/DM-1-200x160.j...             NaN
# 6  GET /wp-content/uploads/2022/07/20200715_10395...             NaN
# 7  GET /shop/figures/slot-track-scenics-figures/f...             NaN
# 8  GET /shop/fencing-tyres-and-covers/fencing/tc-...             NaN
# 9  GET /blog/wp-content/plugins/epoll-wp-voting/r...             NaN
#
#    request_netloc                                       request_path  \
# 0             NaN  GET /home-track-pit-lane-2/pit-lane-version-2b...
# 1             NaN  GET /wp-content/uploads/2015/11/Pit-Lane-versi...
# 2             NaN               GET /shop/adverts/advert-boards-3-a/
# 3             NaN          GET /shop/trackside-extras/bv-burger-van/
# 4             NaN  GET /shop/figures/sra-figures/sra-06-pit-crew-...
# 5             NaN  GET /wp-content/uploads/2019/05/DM-1-200x160.j...
# 6             NaN  GET /wp-content/uploads/2022/07/20200715_10395...
# 7             NaN  GET /shop/figures/slot-track-scenics-figures/f...
# 8             NaN  GET /shop/fencing-tyres-and-covers/fencing/tc-...
# 9             NaN  GET /blog/wp-content/plugins/epoll-wp-voting/r...
#
#                                        request_query  request_fragment  \
# 0                                               None               NaN
# 1                                               None               NaN
# 2   add_to_wishlist=530&_wpnonce=897beb0140 HTTP/1.1               NaN
# 3  add_to_wishlist=1096&_wpnonce=cada0a62b4 HTTP/1.1               NaN
# 4   add_to_wishlist=423&_wpnonce=9c4a8f777b HTTP/1.1               NaN
# 5                                               None               NaN
# 6                                               None               NaN
# 7  add_to_wishlist=8484&_wpnonce=fa0c2ea9a3 HTTP/1.1               NaN
# 8   add_to_wishlist=586&_wpnonce=9636fb532b HTTP/1.1               NaN
# 9                                               None               NaN
#
#   request_dir_1          request_dir_2             request_dir_3  \
# 0          GET   home-track-pit-lane-2  pit-lane-version-2b-copy
# 1          GET              wp-content                   uploads
# 2          GET                    shop                   adverts
# 3          GET                    shop          trackside-extras
# 4          GET                    shop                   figures
# 5          GET              wp-content                   uploads
# 6          GET              wp-content                   uploads
# 7          GET                    shop                   figures
# 8          GET                    shop  fencing-tyres-and-covers
# 9          GET                    blog                wp-content
#
#                 request_dir_4  ... request_query_fbclid request_query_query  \
# 0                        HTTP  ...                 None                 NaN
# 1                        2015  ...                 None                 NaN
# 2           advert-boards-3-a  ...                 None                 NaN
# 3               bv-burger-van  ...                 None                 NaN
# 4                 sra-figures  ...                 None                 NaN
# 5                        2019  ...                 None                 NaN
# 6                        2022  ...                 None                 NaN
# 7  slot-track-scenics-figures  ...                 None                 NaN
# 8                     fencing  ...                 None                 NaN
# 9                     plugins  ...                 None                 NaN
#
#   request_query_post_type request_query_nonce request_query_redirect_to  \
# 0                     NaN                None                      None
# 1                     NaN                None                      None
# 2                     NaN                None                      None
# 3                     NaN                None                      None
# 4                     NaN                None                      None
# 5                     NaN                None                      None
# 6                     NaN                None                      None
# 7                     NaN                None                      None
# 8                     NaN                None                      None
# 9                     NaN                None                      None
#
#   request_query_reauth request_query_t request_query__sm_byp  \
# 0                 None            None                  None
# 1                 None            None                  None
# 2                 None            None                  None
# 3                 None            None                  None
# 4                 None            None                  None
# 5                 None            None                  None
# 6                 None            None                  None
# 7                 None            None                  None
# 8                 None            None                  None
# 9                 None            None                  None
#
#   request_query_step request_query_slug
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# 5                NaN                NaN
# 6                NaN                NaN
# 7                NaN                NaN
# 8                NaN                NaN
# 9                NaN                NaN
#
# [10 rows x 44 columns]

# %%
referer_url_df = adv.url_to_df(logs_df['referer'])
referer_url_df = referer_url_df.add_prefix('referer_')
referer_url_df.head(10)
# Out:
#                                          referer_url referer_scheme  \
# 0                https://www.slottrackscenics.co.uk/          https
# 1  https://www.slottrackscenics.co.uk/home-track-...          https
# 2                                                  -           None
# 3                                                  -           None
# 4                                                  -           None
# 5                                                  -           None
# 6                                                  -           None
# 7                                                  -           None
# 8                                                  -           None
# 9                                                  -           None
#
#                referer_netloc  \
# 0  www.slottrackscenics.co.uk
# 1  www.slottrackscenics.co.uk
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                        referer_path referer_query  \
# 0                                                 /          None
# 1  /home-track-pit-lane-2/pit-lane-version-2b-copy/          None
# 2                                                 -          None
# 3                                                 -          None
# 4                                                 -          None
# 5                                                 -          None
# 6                                                 -          None
# 7                                                 -          None
# 8                                                 -          None
# 9                                                 -          None
#
#   referer_fragment          referer_dir_1             referer_dir_2  \
# 0              NaN                   None                      None
# 1              NaN  home-track-pit-lane-2  pit-lane-version-2b-copy
# 2              NaN                      -                      None
# 3              NaN                      -                      None
# 4              NaN                      -                      None
# 5              NaN                      -                      None
# 6              NaN                      -                      None
# 7              NaN                      -                      None
# 8              NaN                      -                      None
# 9              NaN                      -                      None
#
#   referer_dir_3 referer_dir_4  ... referer_query_fbclid referer_query_s  \
# 0          None          None  ...                 None             NaN
# 1          None          None  ...                 None             NaN
# 2          None          None  ...                 None             NaN
# 3          None          None  ...                 None             NaN
# 4          None          None  ...                 None             NaN
# 5          None          None  ...                 None             NaN
# 6          None          None  ...                 None             NaN
# 7          None          None  ...                 None             NaN
# 8          None          None  ...                 None             NaN
# 9          None          None  ...                 None             NaN
#
#   referer_query__sm_byp referer_query_attachment_id referer_query_q  \
# 0                  None                         NaN             NaN
# 1                  None                         NaN             NaN
# 2                  None                         NaN             NaN
# 3                  None                         NaN             NaN
# 4                  None                         NaN             NaN
# 5                  None                         NaN             NaN
# 6                  None                         NaN             NaN
# 7                  None                         NaN             NaN
# 8                  None                         NaN             NaN
# 9                  None                         NaN             NaN
#
#   referer_query_sa referer_query_ved referer_query_usg referer_hostname  \
# 0              NaN               NaN               NaN              NaN
# 1              NaN               NaN               NaN              NaN
# 2              NaN               NaN               NaN              NaN
# 3              NaN               NaN               NaN              NaN
# 4              NaN               NaN               NaN              NaN
# 5              NaN               NaN               NaN              NaN
# 6              NaN               NaN               NaN              NaN
# 7              NaN               NaN               NaN              NaN
# 8              NaN               NaN               NaN              NaN
# 9              NaN               NaN               NaN              NaN
#
#   referer_dir_6
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
#
# [10 rows x 27 columns]

# %%
ua_df = pd.json_normalize([user_agent_parser.Parse(ua) for ua in logs_df['user_agent']])
ua_df.columns = 'ua_' + ua_df.columns.str.replace('user_agent\.', '', regex=True)
ua_df.head(10)
# Out:
#                                            ua_string ua_family ua_major  \
# 0  Mozilla/5.0 (Linux x86_64; rv:114.0) Gecko/201...   Firefox      114
# 1  Mozilla/5.0 (Linux x86_64; rv:114.0) Gecko/201...   Firefox      114
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    Chrome      104
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    Chrome      104
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...      Edge      101
# 5  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5...  Applebot        0
# 6  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5...  Applebot        0
# 7  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    Chrome      101
# 8  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    Chrome      101
# 9  Mozilla/5.0 (Macintosh; Intel Mac OS X 13_1) A...    Chrome      109
#
#   ua_minor ua_patch ua_os.family ua_os.major ua_os.minor ua_os.patch  \
# 0        0     None        Linux        None        None        None
# 1        0     None        Linux        None        None        None
# 2        0        0      Windows          10        None        None
# 3        0        0      Windows          10        None        None
# 4        0     1210      Windows          10        None        None
# 5        1     None     Mac OS X          10          15           5
# 6        1     None     Mac OS X          10          15           5
# 7        0     4951      Windows          10        None        None
# 8        0     4951      Windows          10        None        None
# 9        0        0     Mac OS X          13           1        None
#
#   ua_os.patch_minor ua_device.family ua_device.brand ua_device.model
# 0              None            Other            None            None
# 1              None            Other            None            None
# 2              None            Other            None            None
# 3              None            Other            None            None
# 4              None            Other            None            None
# 5              None              Mac           Apple             Mac
# 6              None              Mac           Apple             Mac
# 7              None            Other            None            None
# 8              None            Other            None            None
# 9              None              Mac           Apple             Mac

# %%
(pd.concat([logs_df, request_url_df, referer_url_df, ua_df], axis=1)
.to_parquet('data/adv_logs_final.parquet', index=False, version='2.4'))

# %%
top_bots = pd.read_parquet('data/adv_logs_final.parquet',
                filters=[
                    ('ua_device.family', '==', 'Spider')
                ],
                columns=['ua_device.family', 'ua_family'])['ua_family'].value_counts()
top_bots[:15]
# Out:
# FacebookBot        351
# bingbot            215
# SemrushBot         135
# Googlebot-Image    102
# Googlebot           88
# AhrefsBot           75
# Pinterestbot        12
# WordPress            3
# YandexImages         2
# ImagesiftBot         2
# BingPreview          1
# DuckDuckBot          1
# Name: ua_family, dtype: int64
